# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
a = [1, 2,3,4
     ,5, 6]
a
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a = [ 1 # this is a comment
     , 2]

# %%
a
# Out:
# [1, 2]

# %%
a = (1
     , 2 # this is a comment
     , 3 # this is a comment
     )

# %%
a
# Out:
# (1, 2, 3)

# %%
a = 5
b = 6
c = 7

# %% [markdown]
# Conditionals

# %%
if a > b and \
    b > c:
    print("a is greater than b and b is greater than c")
else:
    print("a is not greater than b or b is not greater than c")
# Out:
# a is not greater than b or b is not greater than c

# %%
a =6
if a < 5:
    print("a < 5")
elif a < 10:
    print("5 <= a  < 10")
else:
    print("a > 10")
# Out:
# 5 <= a  < 10

# %%
a = 6
b = "a < 5" if a < 5 else "b >= 5"
print(b)
# Out:
# b >= 5

# %% [markdown]
# Functions

# %%
s = [1,2,3,4,5]
len(s)
# Out:
# 5

# %%
from math import sqrt
sqrt(5)
# Out:
# 2.23606797749979

# %%
def func_1():
    print("This is a function")

# %%
func_1
# Out:
# <function __main__.func_1()>

# %%
func_1()
# Out:
# This is a function

# %%
type(func_1)
# Out:
# function

# %%
type(func_1())
# Out:
# This is a function
# NoneType

# %%
def func_2(a:int, b:int):
    print(a + b)

# %%
func_2(3, 5)
# Out:
# 8

# %%
lambda x: x + 2
# Out:
# <function __main__.<lambda>(x)>

# %%
func_lambda = lambda x : x + 2

# %%
func_lambda(3)
# Out:
# 5

# %% [markdown]
# While loop

# %%
i = 0
while i < 5:
    print(f"value of i is: {i}")
    i+=1
# Out:
# value of i is: 0
# value of i is: 1
# value of i is: 2
# value of i is: 3
# value of i is: 4

# %%
i = 3
while True:
    print(f"value of i:{i}")
    if i >= 5:
        print(f"value of i: {i} >= 5, breaking out of while loop")
        break
    i += 1
# Out:
# value of i:3
# value of i:4
# value of i:5
# value of i: 5 >= 5, breaking out of while loop

# %%
min_length = 5

while True:
    name = input("Enter your name: ")
    if len(name) >= min_length and name.isprintable() and name.isalpha():
        print("Conditions met, breaking")
        break
    else:
        print("Conditions have not met, let's retry again.")

print(f"Hello, {name}")
# Out:
# Conditions have not met, let's retry again.
# Conditions have not met, let's retry again.
# Conditions have not met, let's retry again.
# Conditions met, breaking
# Hello, sesath

# %%
a = 0

while a < 10:
    a += 1
    if a % 2 == 0:
        continue
    print(a)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
# l = [1,10,2,3]
l = [1,2,4]
val = 10

idx = 0

while idx < len(l):
    if l[idx] == val:
        print(f"found {val} on index {idx}")
        break
    idx += 1
else:
    print(f"Couldn't find val: {val} in l: {l}, appending val")
    l.append(val)
    print(l)
# Out:
# Couldn't find val: 10 in l: [1, 2, 4], appending val
# [1, 2, 4, 10]

# %% [markdown]
# Break, Continue and Try statement

# %%
a = 10
b = 0

try:
    print(a/b)
except ZeroDivisionError as e:
    print(f"error : {e}")
finally:
    print("This always executes")
# Out:
# error : division by zero
# This always executes

# %%
a = 1
b = 2

while a < 4:
    a += 1
    b -= 1
    print("------------------------------------")
    try:
        result = a/b
        print(f"main loop, a: {a} / b: {b} = {result}")
    except ZeroDivisionError as e:
        print(f"except block, a: {a} / b: {b} = {e}")
        print("will continue")
        continue
    finally:
        print(f"finally block, a: {a} / b: {b}")
        print("$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$")
else:
    print("runs if no break occured in while loop")
# Out:
# ------------------------------------
# main loop, a: 2 / b: 1 = 2.0
# finally block, a: 2 / b: 1
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# ------------------------------------
# except block, a: 3 / b: 0 = division by zero
# will continue
# finally block, a: 3 / b: 0
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# ------------------------------------
# main loop, a: 4 / b: -1 = -4.0
# finally block, a: 4 / b: -1
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# runs if no break occured in while loop

# %% [markdown]
# For loop

# %%
for i in range(5):
    print(f"value of i is: {i}")
# Out:
# value of i is: 0
# value of i is: 1
# value of i is: 2
# value of i is: 3
# value of i is: 4

# %%
for i, j in [(1,3), (5,6), (8,0)]:
    print(i, j)
# Out:
# 1 3
# 5 6
# 8 0

# %%
for i in range(5):
    if i == 3: continue
    print(i)
# Out:
# 0
# 1
# 2
# 4

# %%
for i in range(5):
    if i ==3: break
    print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(1, 5):
    print(i)
    if i % 7 == 0:
        print("found a multiple of 7: {i}")
        break
else:
    print("found no multiples of 7")
# Out:
# 1
# 2
# 3
# 4
# found no multiples of 7

# %%
for i in range(1, 25):
    print(i)
    if i % 7 == 0:
        print("found a multiple of 7: {i}")
        break
else:
    print("found no multiples of 7")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# found a multiple of 7: {i}

# %%
for i in range(5):
    try:
        print("------------------------")
        print(10/(i-3))
    except ZeroDivisionError:
        print("Got ZeroDivisionError")
        continue
    finally:
        print("Always print after an exception")
    print(i)
# Out:
# ------------------------
# -3.3333333333333335
# Always print after an exception
# 0
# ------------------------
# -5.0
# Always print after an exception
# 1
# ------------------------
# -10.0
# Always print after an exception
# 2
# ------------------------
# Got ZeroDivisionError
# Always print after an exception
# ------------------------
# 10.0
# Always print after an exception
# 4

# %%
for c in "sesath dissanayake":
    print(c)
# Out:
# s
# e
# s
# a
# t
# h
#
# d
# i
# s
# s
# a
# n
# a
# y
# a
# k
# e

# %%
for i, c in enumerate("hello"):
    print(i, c)
# Out:
# 0 h
# 1 e
# 2 l
# 3 l
# 4 o

# %% [markdown]
# Classes

# %%
class Rectangle:
    def __init__(self, width, height) -> None:
        self.width = width
        self.height = height

# %%
r1 = Rectangle(10, 20)

r1.width
# Out:
# 10

# %%
class Rectangle:
    def __init__(self, width, height) -> None:
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height
    
    def perimeter(self):
        return 2 * (self.width + self.height)

# %%
r1 = Rectangle(10, 20)

# %%
r1.area()
# Out:
# 200

# %%
r1.perimeter()
# Out:
# 60

# %%
class Rectangle:
    def __init__(self, width, height) -> None:
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height
    
    def perimeter(self):
        return 2 * (self.width + self.height)
    
    def __str__(self) -> str:
        return f"Rectangle with height: {self.height} and width: {self.width}"

# %%
r1 = Rectangle(10, 20)

# %%
str(r1)
# Out:
# 'Rectangle with height: 20 and width: 10'

# %%
r1

# %%
class Rectangle:
    def __init__(self, width, height) -> None:
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height
    
    def perimeter(self):
        return 2 * (self.width + self.height)
    
    def __str__(self) -> str:
        return f"Rectangle with height: {self.height} and width: {self.width}"
    
    def __repr__(self) -> str:
        return f"Rectangle({self.width}, {self.height})"

# %%
r1 = Rectangle(10, 20)

# %%
r1
# Out:
# Rectangle(10, 20)

# %%
r2 = Rectangle(10, 20)

# %%
r1 is not r2
# Out:
# True

# %%
r1 == r2
# Out:
# False

# %%
class Rectangle:
    def __init__(self, width, height) -> None:
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height
    
    def perimeter(self):
        return 2 * (self.width + self.height)
    
    def __str__(self) -> str:
        return f"Rectangle with height: {self.height} and width: {self.width}"
    
    def __repr__(self) -> str:
        return f"Rectangle({self.width}, {self.height})"
    
    def __eq__(self, value: Rectangle) -> bool:
        return self.width == value.width and self.height == value.height

# %%
r1 = Rectangle(10, 20)

# %%
r2 = Rectangle(10, 20)

# %%
r1 == r2
# Out:
# True

# %%
r1 == 2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 r1 == 2
#
# Cell In[19], line 19, in Rectangle.__eq__(self, value)
#      18 def __eq__(self, value: Rectangle) -> bool:
# ---> 19     return self.width == value.width and self.height == value.height
#
# AttributeError: 'int' object has no attribute 'width'

# %%
class Rectangle:
    def __init__(self, width, height) -> None:
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height
    
    def perimeter(self):
        return 2 * (self.width + self.height)
    
    def __str__(self) -> str:
        return f"Rectangle with height: {self.height} and width: {self.width}"
    
    def __repr__(self) -> str:
        return f"Rectangle({self.width}, {self.height})"
    
    def __eq__(self, value: object) -> bool:
        if isinstance(value, self.__class__):
            return self.width == value.width and self.height == value.height
        else:
            print("we can only compare Rectangle objects")
            return False

# %%
r1= Rectangle(10, 20)

# %%
r1 == 20
# Out:
# we can only compare Rectangle objects
# False

# %%
class Rectangle:
    def __init__(self, width, height) -> None:
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height
    
    def perimeter(self):
        return 2 * (self.width + self.height)
    
    def __str__(self) -> str:
        return f"Rectangle with height: {self.height} and width: {self.width}"
    
    def __repr__(self) -> str:
        return f"Rectangle({self.width}, {self.height})"
    
    def __eq__(self, value: object) -> bool:
        if isinstance(value, self.__class__):
            return self.width == value.width and self.height == value.height
        else:
            print("we can only compare Rectangle objects")
            return False
    
    def __lt__(self, value:object):
        if isinstance(value, self.__class__):
            return self.area() < value.area()
        else:
            return NotImplemented

# %%
r1 = Rectangle(100, 200)
r2 = Rectangle(10, 20)

# %%
r1 < r2
# Out:
# False

# %%
r2 < r1
# Out:
# True

# %%
class Rectangle:
    def __init__(self, width, height) -> None:
        self._width = width
        self._height = height

# %%
r1 = Rectangle(10, 20)

# %%
r1._height
# Out:
# 20

# %%
r1.width
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 r1.width
#
# AttributeError: 'Rectangle' object has no attribute 'width'

# %%
r1.width = 1000

# %%
r1.width
# Out:
# 1000

# %% [markdown]
# monkey patching
#
# Monkey patching refers to the practice of dynamically modifying or extending the behavior of existing code at runtime. In this case, you are "patching" the r1 object by adding a new attribute (width) that wasn't originally defined in the Rectangle class.

# %%
class Rectangle:
    def __init__(self, width, height) -> None:
        self._width = width
        self._height = height

    @property
    def width(self):
        return self._width
    
    @width.setter
    def width(self, value):
        if value <= 0:
            raise ValueError(f"Width must be greater than zero and not {value}")
        else:
            self._width = value

    @property
    def height(self):
        return self._height
    
    @height.setter
    def height(self, value):
        if value <= 0:
            raise ValueError(f"Height must be greater than zero and not {value}")
        else:
            self._height = value
    
    def __repr__(self) -> str:
        return f"Rectangle({self.width}, {self.height})"

# %%
r1= Rectangle(10, 20)

# %%
r1
# Out:
# Rectangle(10, 20)

# %%
r1.height = 300

# %%
r1
# Out:
# Rectangle(10, 300)

# %%
r1.height = -22
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 r1.height = -22
#
# Cell In[42], line 24, in Rectangle.height(self, value)
#      21 @height.setter
#      22 def height(self, value):
#      23     if value <= 0:
# ---> 24         raise ValueError(f"Height must be greater than zero and not {value}")
#      25     else:
#      26         self._height = value
#
# ValueError: Height must be greater than zero and not -22

# %%
r1= Rectangle(-10, 20)

# %%
r1
# Out:
# Rectangle(-10, 20)

# %%
class Rectangle:
    def __init__(self, width, height) -> None:
        self._width = None
        self._height = None

        self.width = width
        self.height = height

    @property
    def width(self):
        return self._width
    
    @width.setter
    def width(self, value):
        if value <= 0:
            raise ValueError(f"Width must be greater than zero and not {value}")
        else:
            self._width = value

    @property
    def height(self):
        return self._height
    
    @height.setter
    def height(self, value):
        if value <= 0:
            raise ValueError(f"Height must be greater than zero and not {value}")
        else:
            self._height = value
    
    def __repr__(self) -> str:
        return f"Rectangle({self.width}, {self.height})"

# %%
r1= Rectangle(-10, 20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 r1= Rectangle(-10, 20)
#
# Cell In[56], line 6, in Rectangle.__init__(self, width, height)
#       3 self._width = None
#       4 self._height = None
# ----> 6 self.width = width
#       7 self.height = height
#
# Cell In[56], line 16, in Rectangle.width(self, value)
#      13 @width.setter
#      14 def width(self, value):
#      15     if value <= 0:
# ---> 16         raise ValueError(f"Width must be greater than zero and not {value}")
#      17     else:
#      18         self._width = value
#
# ValueError: Width must be greater than zero and not -10
